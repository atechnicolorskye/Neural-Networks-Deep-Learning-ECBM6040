# %%
"""
Source Code for Homework 3.a of ECBM E6040, Spring 2016, Columbia University

Instructor: Prof. Aurel A. Lazar

This code is based on
[1] http://deeplearning.net/tutorial/logreg.html
[2] http://deeplearning.net/tutorial/mlp.html
[3] http://deeplearning.net/tutorial/lenet.html
"""

import matplotlib as mpl
mpl.use('Agg')
import matplotlib.pyplot as plt
import numpy
import pickle
import theano
from theano import function
import theano.tensor as T

from hw3_utils import shared_dataset, load_data
from hw3_nn import LogisticRegression, HiddenLayer, myMLP, LeNetConvPoolLayer, train_nn


# TODO
def input_noise_injection(array, array_shape, noise_type, rng):
    # (13186, 3072)
    # (13186,)
    # (65930, 3072)
    # (65930,)
    if noise_type == 'normal':
        rv = rng.normal(scale=0.01, size=array_shape)
    elif noise_type == 'uniform':
        rv = rng.uniform(low=-0.5, high=0.5, size=array_shape)
    # rv = rv.astype('float32')
    # print array., rv.dtype
    # print array_shape, rv.shape
    output = array + rv.astype('float32')
    print output.shape.eval()
    return output 

def weight_noise_injection(array_shape, noise_type, scale, rng):
    # (13186, 3072)
    # (13186,)
    # (65930, 3072)
    # (65930,)
    noise = []
    
    for i in range(len(array_shape)):
        if i % 2 == 0: # and i <= len(array_shape) - 3:
            if noise_type == 'normal':
                rv = rng.normal(scale=scale, size=array_shape[i])
                print rv.shape
                noise.append(rv.astype('float32'))
            elif noise_type == 'uniform':
                rv = rng.uniform(low=-scale, high=scale, size=array_shape[i])
                print rv.shape
                noise.append(rv.astype('float32'))
        else:
            rv = numpy.zeros(array_shape[i])
            print '0', rv.shape
            noise.append(rv.astype('float32'))
    return noise
        
# TODO
def translate_image(array, direction, size):
    if direction == 'up':
        # Remove last 32 * 3 numbers and pad the end with 0s
        return numpy.hstack((array[:, :array.shape[1] - (size * 3)], numpy.zeros((array.shape[0], size * 3))))
    elif direction == 'down':
        # Remove first 32 * 3 numbers and pad the start with 0s
        return numpy.hstack((numpy.zeros((array.shape[0], size * 3)), array[:, size * 3:]))
    elif direction == 'left':
        # Remove for 0 to 31, the first three numbers of each row and add three numbers to the end of each row
        for i in range(size):
            return numpy.hstack((array[:, (i + 1) * size - (size - 3):(i + 1) * size], numpy.zeros((array.shape[0], 3))))
    elif direction == 'right':
        # Reverse of left
        for i in range(size):
            return numpy.hstack((numpy.zeros((array.shape[0], 3)), array[:, i * size:(i + 1) * size - 3]))

# TODO
def test_noise_inject_at_weight(learning_rate=0.01,
             L1_reg=0.00, L2_reg=0.0001, n_epochs=100,
             batch_size=128, n_hidden=500, n_hiddenLayers=3, scale=0.001,
             verbose=False, noise_type='normal'):
    """
    Wrapper function for experiment of noise injection at weights

    :type learning_rate: float
    :param learning_rate: learning rate used (factor for the stochastic
    gradient.

    :type L1_reg: float
    :param L1_reg: L1-norm's weight when added to the cost (see
    regularization).

    :type L2_reg: float
    :param L2_reg: L2-norm's weight when added to the cost (see
    regularization).

    :type n_epochs: int
    :param n_epochs: maximal number of epochs to run the optimizer.

    :type batch_size: int
    :param batch_szie: number of examples in minibatch.

    :type n_hidden: int or list of ints
    :param n_hidden: number of hidden units. If a list, it specifies the
    number of units in each hidden layers, and its length should equal to
    n_hiddenLayers.

    :type n_hiddenLayers: int
    :param n_hiddenLayers: number of hidden layers.

    :type verbose: boolean
    :param verbose: to print out epoch summary or not to.

    :type smaller_set: boolean
    :param smaller_set: to use the smaller dataset or not to.

    """
    rng = numpy.random.RandomState(23455)

    # Load down-sampled dataset in raw format (numpy.darray, not Theano.shared)
    # train_set, valid_set, test_set format: tuple(input, target)
    # input is a numpy.ndarray of 2 dimensions (a matrix), where each row
    # corresponds to an example. target is a numpy.ndarray of 1 dimension
    # (vector) that has the same length as the number of rows in the input.

    # Load the smaller dataset
    datasets = load_data(ds_rate=5)

    train_set_x, train_set_y = datasets[0]
    valid_set_x, valid_set_y = datasets[1]
    test_set_x, test_set_y = datasets[2]

    # compute number of minibatches for training, validation and testing
    n_train_batches = train_set_x.get_value(borrow=True).shape[0]
    n_valid_batches = valid_set_x.get_value(borrow=True).shape[0]
    n_test_batches = test_set_x.get_value(borrow=True).shape[0]
    n_train_batches //= batch_size
    n_valid_batches //= batch_size
    n_test_batches //= batch_size

    # allocate symbolic variables for the data
    index = T.lscalar()  # index to a [mini]batch

    x = T.matrix('x')   # the data is presented as rasterized images
    y = T.ivector('y')  # the labels are presented as 1D vector of
                        # [int] labels

    ######################
    # BUILD ACTUAL MODEL #
    ######################
    print('... building the model')

    # allocate symbolic variables for the data
    index = T.lscalar()  # index to a [mini]batch
    x = T.matrix('x')  # the data is presented as rasterized images
    y = T.ivector('y')  # the labels are presented as 1D vector of
                        # [int] labels

    rng = numpy.random.RandomState(1234)

    classifier = myMLP(
        rng=rng,
        input=x,
        n_in=32*32*3,
        n_hidden=n_hidden,
        n_hiddenLayers=n_hiddenLayers,
        n_out=10
    )

    # the cost we minimize during training is the negative log likelihood of
    # the model plus the regularization terms (L1 and L2); cost is expressed
    # here symbolically
    cost = (
        classifier.negative_log_likelihood(y)
        + L1_reg * classifier.L1
        + L2_reg * classifier.L2_sqr
    )

    # compiling a Theano function that computes the mistakes that are made
    # by the model on a minibatch
    test_model = theano.function(
        inputs=[index],
        outputs=classifier.errors(y),
        givens={
            x: test_set_x[index * batch_size:(index + 1) * batch_size],
            y: test_set_y[index * batch_size:(index + 1) * batch_size]
        }
    )

    validate_model = theano.function(
        inputs=[index],
        outputs=classifier.errors(y),
        givens={
            x: valid_set_x[index * batch_size:(index + 1) * batch_size],
            y: valid_set_y[index * batch_size:(index + 1) * batch_size]
        }
    )

    # compute the gradient of cost with respect to theta (sorted in params)
    # the resulting gradients will be stored in a list gparams
    gparams = [T.grad(cost, param) for param in classifier.params]

    # specify how to update the parameters of the model as a list of
    # (variable, update expression) pairs

    # given two lists of the same length, A = [a1, a2, a3, a4] and
    # B = [b1, b2, b3, b4], zip generates a list C of same size, where each
    # element is a pair formed from the two lists :
    #    C = [(a1, b1), (a2, b2), (a3, b3), (a4, b4)]

    # TODO: modify updates to inject noise to the weight
    # Reminder: self.params = [self.W, self.b]
    print [param for param in classifier.params]
    print [param.shape.eval() for param in classifier.params]
    print len(classifier.params)
    
    updates = [
        (param, param - learning_rate * gparam + noise)
        for param, gparam, noise in zip(classifier.params, gparams, weight_noise_injection([param.shape.eval() for param in classifier.params], noise_type, scale, rng))
    ]

    # compiling a Theano function `train_model` that returns the cost, but
    # in the same time updates the parameter of the model based on the rules
    # defined in `updates`
    train_model = theano.function(
        inputs=[index],
        outputs=cost,
        updates=updates,
        givens={
            x: train_set_x[index * batch_size: (index + 1) * batch_size],
            y: train_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )

    ###############
    # TRAIN MODEL #
    ###############
    print('... training')

    train_nn(train_model, validate_model, test_model,
        n_train_batches, n_valid_batches, n_test_batches, n_epochs, verbose)
    
def test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=100,
             batch_size=128, n_hidden=500, n_hiddenLayers=3,
             verbose=False, smaller_set=True):
    """
    Wrapper function for training and testing MLP

    :type learning_rate: float
    :param learning_rate: learning rate used (factor for the stochastic
    gradient.

    :type L1_reg: float
    :param L1_reg: L1-norm's weight when added to the cost (see
    regularization).

    :type L2_reg: float
    :param L2_reg: L2-norm's weight when added to the cost (see
    regularization).

    :type n_epochs: int
    :param n_epochs: maximal number of epochs to run the optimizer.

    :type batch_size: int
    :param batch_szie: number of examples in minibatch.

    :type n_hidden: int or list of ints
    :param n_hidden: number of hidden units. If a list, it specifies the
    number of units in each hidden layers, and its length should equal to
    n_hiddenLayers.

    :type n_hiddenLayers: int
    :param n_hiddenLayers: number of hidden layers.

    :type verbose: boolean
    :param verbose: to print out epoch summary or not to.

    :type smaller_set: boolean
    :param smaller_set: to use the smaller dataset or not to.

    """
    # load the dataset; download the dataset if it is not present
    if smaller_set:
        datasets = load_data(ds_rate=5)
    else:
        datasets = load_data()

    train_set_x, train_set_y = datasets[0]
    valid_set_x, valid_set_y = datasets[1]
    test_set_x, test_set_y = datasets[2]

    # compute number of minibatches for training, validation and testing
    n_train_batches = train_set_x.get_value(borrow=True).shape[0] // batch_size
    n_valid_batches = valid_set_x.get_value(borrow=True).shape[0] // batch_size
    n_test_batches = test_set_x.get_value(borrow=True).shape[0] // batch_size

    ######################
    # BUILD ACTUAL MODEL #
    ######################
    print('... building the model')

    # allocate symbolic variables for the data
    index = T.lscalar()  # index to a [mini]batch
    x = T.matrix('x')  # the data is presented as rasterized images
    y = T.ivector('y')  # the labels are presented as 1D vector of
                        # [int] labels

    rng = numpy.random.RandomState(1234)

    # TODO: construct a neural network, either MLP or CNN.
    classifier = myMLP(
       rng=rng,
       input=x,
       n_in=32*32*3,
       n_hidden=n_hidden,
       n_out=10,
       n_hiddenLayers=n_hiddenLayers
    )

    # the cost we minimize during training is the negative log likelihood of
    # the model plus the regularization terms (L1 and L2); cost is expressed
    # here symbolically
    cost = (
        classifier.negative_log_likelihood(y)
        + L1_reg * classifier.L1
        + L2_reg * classifier.L2_sqr
    )

    # compiling a Theano function that computes the mistakes that are made
    # by the model on a minibatch
    test_model = theano.function(
        inputs=[index],
        outputs=classifier.errors(y),
        givens={
            x: test_set_x[index * batch_size:(index + 1) * batch_size],
            y: test_set_y[index * batch_size:(index + 1) * batch_size]
        }
    )

    validate_model = theano.function(
        inputs=[index],
        outputs=classifier.errors(y),
        givens={
            x: valid_set_x[index * batch_size:(index + 1) * batch_size],
            y: valid_set_y[index * batch_size:(index + 1) * batch_size]
        }
    )

    # compute the gradient of cost with respect to theta (sotred in params)
    # the resulting gradients will be stored in a list gparams
    gparams = [T.grad(cost, param) for param in classifier.params]

    # specify how to update the parameters of the model as a list of
    # (variable, update expression) pairs

    # given two lists of the same length, A = [a1, a2, a3, a4] and
    # B = [b1, b2, b3, b4], zip generates a list C of same size, where each
    # element is a pair formed from the two lists :
    #    C = [(a1, b1), (a2, b2), (a3, b3), (a4, b4)]
    updates = [
        (param, param - learning_rate * gparam)
        for param, gparam in zip(classifier.params, gparams)
    ]

    # compiling a Theano function `train_model` that returns the cost, but
    # in the same time updates the parameter of the model based on the rules
    # defined in `updates`
    train_model = theano.function(
        inputs=[index],
        outputs=cost,
        updates=updates,
        givens={
            x: train_set_x[index * batch_size: (index + 1) * batch_size],
            y: train_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )

    ###############
    # TRAIN MODEL #
    ###############
    print('... training')

    train_nn(train_model, validate_model, test_model,
        n_train_batches, n_valid_batches, n_test_batches, n_epochs, verbose)

#     with open('list_weight', 'w') as F:
#         pickle.dump([numpy.array(p.eval()) for p in classifier.params], F)
        
    g_adv = T.grad(cost, classifier.input)
    
    gradient = theano.function(
        inputs=[index],
        outputs=g_adv,
        givens={
            x: train_set_x[index:index+1],
            y: train_set_y[index:index+1]
        }
    )
    
#     print test_set_x.shape.eval(), test_set_x[0,:].shape.eval(), gradient(0).shape
    
    # %matplotlib inline
    
    img = test_set_x[0,:].eval().reshape((32, 32, 3))
    
    img_add = train_set_x[0,:].eval().reshape((32, 32, 3))
    
    img_grad = gradient(0).reshape((32, 32, 3))
    
    plt.figure()
    plt.imshow(img)
    
    plt.figure()
    plt.imshow(img_add)
    
    plt.figure()
    plt.imshow(img_grad)
    
    test_set_x_adv = test_set_x[0,:] + 0.05 * gradient(0).reshape(-1,)
    
#     test_set_x[0][0] += 0.01 * gradient(0).reshape(-1,)
    
    test_set_x_adv = test_set_x_adv.reshape(gradient(0).shape)
    
    img_adv = test_set_x_adv.eval().reshape((32, 32, 3))
 
    plt.figure()
    plt.imshow(img_adv)
    
#     print test_set_x_adv.shape.eval()
    
    test_model_adv = theano.function(
        inputs=[index],
        outputs=classifier.errors(y),
        givens={
            x: test_set_x_adv[index:index+1],
            y: test_set_y[index:index+1]
        }
    )
    
    test_model_norm = theano.function(
        inputs=[index],
        outputs=classifier.errors(y),
        givens={
            x: test_set_x[index:index+1],
            y: test_set_y[index:index+1]
        }
    )
    
    print test_model_norm(0), test_model_adv(0)

# %%
test_noise_inject_at_weight(learning_rate=0.01,
             L1_reg=0.00, L2_reg=0.0001, n_epochs=100,
             batch_size=128, n_hidden=500, n_hiddenLayers=3, scale=0.001,
             verbose=False, noise_type='normal')
# Out:
# ... building the model
# [W, b, W, b, W, b, W, b]
# [array([3072,  500]), array([500]), array([500, 500]), array([500]), array([500, 500]), array([500]), array([500,  10]), array([10])]
# 8
# (3072, 500)
# 0 (500,)
# (500, 500)
# 0 (500,)
# (500, 500)
# 0 (500,)
# (500, 10)
# 0 (10,)
# ... training
# training @ iter =  0
# training @ iter =  100
# epoch 1, minibatch 103/103, validation error 82.954545 %
#      epoch 1, minibatch 103/103, test error of best model 83.004926 %
# training @ iter =  200
# epoch 2, minibatch 103/103, validation error 80.965909 %
#      epoch 2, minibatch 103/103, test error of best model 78.525246 %
# training @ iter =  300
# epoch 3, minibatch 103/103, validation error 83.096591 %
# training @ iter =  400
# epoch 4, minibatch 103/103, validation error 83.451705 %
# training @ iter =  500
# epoch 5, minibatch 103/103, validation error 83.948864 %
# training @ iter =  600
# epoch 6, minibatch 103/103, validation error 83.948864 %
# training @ iter =  700
# epoch 7, minibatch 103/103, validation error 84.019886 %
# training @ iter =  800
# epoch 8, minibatch 103/103, validation error 83.522727 %
# training @ iter =  900
# epoch 9, minibatch 103/103, validation error 85.298295 %
# training @ iter =  1000
# epoch 10, minibatch 103/103, validation error 84.659091 %
# training @ iter =  1100
# epoch 11, minibatch 103/103, validation error 84.517045 %
# training @ iter =  1200
# epoch 12, minibatch 103/103, validation error 85.440341 %
# training @ iter =  1300
# epoch 13, minibatch 103/103, validation error 84.588068 %
# training @ iter =  1400
# epoch 14, minibatch 103/103, validation error 84.872159 %
# training @ iter =  1500
# epoch 15, minibatch 103/103, validation error 84.517045 %
# training @ iter =  1600
# epoch 16, minibatch 103/103, validation error 84.588068 %
# training @ iter =  1700
# epoch 17, minibatch 103/103, validation error 85.369318 %
# training @ iter =  1800
# epoch 18, minibatch 103/103, validation error 84.446023 %
# training @ iter =  1900
# epoch 19, minibatch 103/103, validation error 85.369318 %
# training @ iter =  2000
# epoch 20, minibatch 103/103, validation error 84.375000 %
# training @ iter =  2100
# epoch 21, minibatch 103/103, validation error 85.085227 %
# training @ iter =  2200
# epoch 22, minibatch 103/103, validation error 84.090909 %
# training @ iter =  2300
# epoch 23, minibatch 103/103, validation error 84.446023 %
# training @ iter =  2400
# epoch 24, minibatch 103/103, validation error 83.806818 %
# training @ iter =  2500
# epoch 25, minibatch 103/103, validation error 84.659091 %
# training @ iter =  2600
# epoch 26, minibatch 103/103, validation error 84.161932 %
# training @ iter =  2700
# epoch 27, minibatch 103/103, validation error 84.019886 %
# training @ iter =  2800
# epoch 28, minibatch 103/103, validation error 83.451705 %
# training @ iter =  2900
# epoch 29, minibatch 103/103, validation error 85.085227 %
# training @ iter =  3000
# epoch 30, minibatch 103/103, validation error 84.232955 %
# training @ iter =  3100
# epoch 31, minibatch 103/103, validation error 84.588068 %
# training @ iter =  3200
# epoch 32, minibatch 103/103, validation error 84.517045 %
# training @ iter =  3300
# epoch 33, minibatch 103/103, validation error 84.659091 %
# training @ iter =  3400
# training @ iter =  3500
# epoch 34, minibatch 103/103, validation error 84.588068 %
# training @ iter =  3600
# epoch 35, minibatch 103/103, validation error 84.730114 %
# training @ iter =  3700
# epoch 36, minibatch 103/103, validation error 85.440341 %
# training @ iter =  3800
# epoch 37, minibatch 103/103, validation error 84.872159 %
# training @ iter =  3900
# epoch 38, minibatch 103/103, validation error 83.522727 %
# training @ iter =  4000
# epoch 39, minibatch 103/103, validation error 84.303977 %
# training @ iter =  4100
# epoch 40, minibatch 103/103, validation error 84.232955 %
# training @ iter =  4200
# epoch 41, minibatch 103/103, validation error 86.789773 %
# training @ iter =  4300
# epoch 42, minibatch 103/103, validation error 85.937500 %
# training @ iter =  4400
# epoch 43, minibatch 103/103, validation error 88.281250 %
# training @ iter =  4500
# epoch 44, minibatch 103/103, validation error 86.079545 %
# training @ iter =  4600
# epoch 45, minibatch 103/103, validation error 85.937500 %
# training @ iter =  4700
# epoch 46, minibatch 103/103, validation error 85.440341 %
# training @ iter =  4800
# epoch 47, minibatch 103/103, validation error 85.511364 %
# training @ iter =  4900
# epoch 48, minibatch 103/103, validation error 84.659091 %
# training @ iter =  5000
# epoch 49, minibatch 103/103, validation error 84.872159 %
# training @ iter =  5100
# epoch 50, minibatch 103/103, validation error 85.156250 %
# training @ iter =  5200
# epoch 51, minibatch 103/103, validation error 85.156250 %
# training @ iter =  5300
# epoch 52, minibatch 103/103, validation error 84.232955 %
# training @ iter =  5400
# epoch 53, minibatch 103/103, validation error 83.238636 %
# training @ iter =  5500
# epoch 54, minibatch 103/103, validation error 85.937500 %
# training @ iter =  5600
# epoch 55, minibatch 103/103, validation error 84.872159 %
# training @ iter =  5700
# epoch 56, minibatch 103/103, validation error 86.860795 %
# training @ iter =  5800
# epoch 57, minibatch 103/103, validation error 86.576705 %
# training @ iter =  5900
# epoch 58, minibatch 103/103, validation error 85.866477 %
# training @ iter =  6000
# epoch 59, minibatch 103/103, validation error 83.167614 %
# training @ iter =  6100
# epoch 60, minibatch 103/103, validation error 84.801136 %
# training @ iter =  6200
# epoch 61, minibatch 103/103, validation error 85.014205 %
# training @ iter =  6300
# epoch 62, minibatch 103/103, validation error 84.659091 %
# training @ iter =  6400
# epoch 63, minibatch 103/103, validation error 85.298295 %
# training @ iter =  6500
# epoch 64, minibatch 103/103, validation error 85.227273 %
# training @ iter =  6600
# epoch 65, minibatch 103/103, validation error 84.659091 %
# training @ iter =  6700
# epoch 66, minibatch 103/103, validation error 84.303977 %
# training @ iter =  6800
# training @ iter =  6900
# epoch 67, minibatch 103/103, validation error 84.019886 %
# training @ iter =  7000
# epoch 68, minibatch 103/103, validation error 83.806818 %
# training @ iter =  7100
# epoch 69, minibatch 103/103, validation error 89.488636 %
# training @ iter =  7200
# epoch 70, minibatch 103/103, validation error 84.019886 %
# training @ iter =  7300
# epoch 71, minibatch 103/103, validation error 84.943182 %
# training @ iter =  7400
# epoch 72, minibatch 103/103, validation error 84.943182 %
# training @ iter =  7500
# epoch 73, minibatch 103/103, validation error 84.161932 %
# training @ iter =  7600
# epoch 74, minibatch 103/103, validation error 85.085227 %
# training @ iter =  7700
# epoch 75, minibatch 103/103, validation error 83.806818 %
# training @ iter =  7800
# epoch 76, minibatch 103/103, validation error 83.948864 %
# training @ iter =  7900
# epoch 77, minibatch 103/103, validation error 85.156250 %
# training @ iter =  8000
# epoch 78, minibatch 103/103, validation error 85.440341 %
# training @ iter =  8100
# epoch 79, minibatch 103/103, validation error 85.014205 %
# training @ iter =  8200
# epoch 80, minibatch 103/103, validation error 84.161932 %
# training @ iter =  8300
# epoch 81, minibatch 103/103, validation error 83.380682 %
# training @ iter =  8400
# epoch 82, minibatch 103/103, validation error 83.096591 %
# training @ iter =  8500
# epoch 83, minibatch 103/103, validation error 83.593750 %
# training @ iter =  8600
# epoch 84, minibatch 103/103, validation error 84.801136 %
# training @ iter =  8700
# epoch 85, minibatch 103/103, validation error 85.440341 %
# training @ iter =  8800
# epoch 86, minibatch 103/103, validation error 86.292614 %
# training @ iter =  8900
# epoch 87, minibatch 103/103, validation error 88.352273 %
# training @ iter =  9000
# epoch 88, minibatch 103/103, validation error 84.375000 %
# training @ iter =  9100
# epoch 89, minibatch 103/103, validation error 82.812500 %
# training @ iter =  9200
# epoch 90, minibatch 103/103, validation error 85.156250 %
# training @ iter =  9300
# epoch 91, minibatch 103/103, validation error 84.019886 %
# training @ iter =  9400
# epoch 92, minibatch 103/103, validation error 84.801136 %
# training @ iter =  9500
# epoch 93, minibatch 103/103, validation error 84.517045 %
# training @ iter =  9600
# epoch 94, minibatch 103/103, validation error 87.500000 %
# training @ iter =  9700
# epoch 95, minibatch 103/103, validation error 85.653409 %
# training @ iter =  9800
# epoch 96, minibatch 103/103, validation error 84.446023 %
# training @ iter =  9900
# epoch 97, minibatch 103/103, validation error 85.795455 %
# training @ iter =  10000
# epoch 98, minibatch 103/103, validation error 86.292614 %
# training @ iter =  10100
# epoch 99, minibatch 103/103, validation error 87.926136 %
# training @ iter =  10200
# epoch 100, minibatch 103/103, validation error 84.943182 %
# training @ iter =  10300
# training @ iter =  10400
# epoch 101, minibatch 103/103, validation error 85.014205 %
# training @ iter =  10500
# epoch 102, minibatch 103/103, validation error 84.090909 %
# training @ iter =  10600
# epoch 103, minibatch 103/103, validation error 84.446023 %
# training @ iter =  10700
# epoch 104, minibatch 103/103, validation error 83.167614 %
# training @ iter =  10800
# epoch 105, minibatch 103/103, validation error 84.517045 %
# training @ iter =  10900
# epoch 106, minibatch 103/103, validation error 83.593750 %
# training @ iter =  11000
# epoch 107, minibatch 103/103, validation error 84.303977 %
# training @ iter =  11100
# epoch 108, minibatch 103/103, validation error 85.156250 %
# training @ iter =  11200
# epoch 109, minibatch 103/103, validation error 84.517045 %
# training @ iter =  11300
# epoch 110, minibatch 103/103, validation error 84.375000 %
# training @ iter =  11400
# epoch 111, minibatch 103/103, validation error 84.943182 %
# training @ iter =  11500
# epoch 112, minibatch 103/103, validation error 85.440341 %
# training @ iter =  11600
# epoch 113, minibatch 103/103, validation error 86.008523 %
# training @ iter =  11700
# epoch 114, minibatch 103/103, validation error 85.156250 %
# training @ iter =  11800
# epoch 115, minibatch 103/103, validation error 88.778409 %
# training @ iter =  11900
# epoch 116, minibatch 103/103, validation error 85.156250 %
# training @ iter =  12000
# epoch 117, minibatch 103/103, validation error 85.298295 %
# training @ iter =  12100
# epoch 118, minibatch 103/103, validation error 87.571023 %
# training @ iter =  12200
# epoch 119, minibatch 103/103, validation error 88.849432 %
# training @ iter =  12300
# epoch 120, minibatch 103/103, validation error 88.707386 %
# training @ iter =  12400
# epoch 121, minibatch 103/103, validation error 85.582386 %
# training @ iter =  12500
# epoch 122, minibatch 103/103, validation error 86.221591 %
# training @ iter =  12600
# epoch 123, minibatch 103/103, validation error 89.417614 %
# training @ iter =  12700
# epoch 124, minibatch 103/103, validation error 90.269886 %
# training @ iter =  12800
# epoch 125, minibatch 103/103, validation error 87.713068 %
# training @ iter =  12900
# epoch 126, minibatch 103/103, validation error 87.500000 %
# training @ iter =  13000
# epoch 127, minibatch 103/103, validation error 85.937500 %
# training @ iter =  13100
# epoch 128, minibatch 103/103, validation error 86.008523 %
# training @ iter =  13200
# epoch 129, minibatch 103/103, validation error 88.920455 %
# training @ iter =  13300
# epoch 130, minibatch 103/103, validation error 88.352273 %
# training @ iter =  13400
# epoch 131, minibatch 103/103, validation error 90.340909 %
# training @ iter =  13500
# epoch 132, minibatch 103/103, validation error 87.002841 %
# training @ iter =  13600
# epoch 133, minibatch 103/103, validation error 88.991477 %
# training @ iter =  13700
# training @ iter =  13800
# epoch 134, minibatch 103/103, validation error 90.198864 %
# training @ iter =  13900
# epoch 135, minibatch 103/103, validation error 88.778409 %
# training @ iter =  14000
# epoch 136, minibatch 103/103, validation error 86.292614 %

# %%
test_noise_inject_at_weight(learning_rate=0.01,
             L1_reg=0.00, L2_reg=0.0001, n_epochs=500,
             batch_size=128, n_hidden=500, n_hiddenLayers=3,
             verbose=True, noise_type='normal')
# Out:
# ... building the model
# [W, b, W, b, W, b, W, b]
# [array([3072,  500]), array([500]), array([500, 500]), array([500]), array([500, 500]), array([500]), array([500,  10]), array([10])]
# 8
# (3072, 500)
# 0 (500,)
# (500, 500)
# 0 (500,)
# (500, 500)
# 0 (500,)
# (500, 10)
# 0 (10,)
# ... training
# training @ iter =  0
# training @ iter =  100
# epoch 1, minibatch 103/103, validation error 89.630682 %
#      epoch 1, minibatch 103/103, test error of best model 88.131158 %
# training @ iter =  200
# epoch 2, minibatch 103/103, validation error 88.281250 %
#      epoch 2, minibatch 103/103, test error of best model 89.066349 %
# training @ iter =  300
# epoch 3, minibatch 103/103, validation error 87.215909 %
#      epoch 3, minibatch 103/103, test error of best model 88.539101 %
# training @ iter =  400
# epoch 4, minibatch 103/103, validation error 88.494318 %
# training @ iter =  500
# epoch 5, minibatch 103/103, validation error 90.056818 %
# training @ iter =  600
# epoch 6, minibatch 103/103, validation error 88.849432 %
# training @ iter =  700
# epoch 7, minibatch 103/103, validation error 87.713068 %
# training @ iter =  800
# epoch 8, minibatch 103/103, validation error 91.477273 %
# training @ iter =  900
# epoch 9, minibatch 103/103, validation error 85.298295 %
#      epoch 9, minibatch 103/103, test error of best model 87.084360 %
# training @ iter =  1000
# epoch 10, minibatch 103/103, validation error 88.849432 %
# training @ iter =  1100
# epoch 11, minibatch 103/103, validation error 90.411932 %
# training @ iter =  1200
# epoch 12, minibatch 103/103, validation error 88.068182 %
# training @ iter =  1300
# epoch 13, minibatch 103/103, validation error 89.417614 %
# training @ iter =  1400
# epoch 14, minibatch 103/103, validation error 89.559659 %
# training @ iter =  1500
# epoch 15, minibatch 103/103, validation error 89.985795 %
# training @ iter =  1600
# epoch 16, minibatch 103/103, validation error 85.937500 %
# training @ iter =  1700
# epoch 17, minibatch 103/103, validation error 90.696023 %
# training @ iter =  1800
# epoch 18, minibatch 103/103, validation error 87.500000 %
# training @ iter =  1900
# epoch 19, minibatch 103/103, validation error 91.193182 %
# training @ iter =  2000
# epoch 20, minibatch 103/103, validation error 88.991477 %
# training @ iter =  2100
# epoch 21, minibatch 103/103, validation error 87.428977 %
# training @ iter =  2200
# epoch 22, minibatch 103/103, validation error 89.630682 %
# training @ iter =  2300
# epoch 23, minibatch 103/103, validation error 86.079545 %
# training @ iter =  2400
# epoch 24, minibatch 103/103, validation error 90.838068 %
# training @ iter =  2500
# epoch 25, minibatch 103/103, validation error 88.636364 %
# training @ iter =  2600
# epoch 26, minibatch 103/103, validation error 91.619318 %
# training @ iter =  2700
# epoch 27, minibatch 103/103, validation error 90.696023 %
# training @ iter =  2800
# epoch 28, minibatch 103/103, validation error 85.582386 %
# training @ iter =  2900
# epoch 29, minibatch 103/103, validation error 90.980114 %
# training @ iter =  3000
# epoch 30, minibatch 103/103, validation error 87.002841 %
# training @ iter =  3100
# epoch 31, minibatch 103/103, validation error 88.494318 %
# training @ iter =  3200
# epoch 32, minibatch 103/103, validation error 88.849432 %
# training @ iter =  3300
# epoch 33, minibatch 103/103, validation error 88.281250 %
# training @ iter =  3400
# training @ iter =  3500
# epoch 34, minibatch 103/103, validation error 89.630682 %
# training @ iter =  3600
# epoch 35, minibatch 103/103, validation error 88.778409 %
# training @ iter =  3700
# epoch 36, minibatch 103/103, validation error 86.647727 %
# training @ iter =  3800
# epoch 37, minibatch 103/103, validation error 88.565341 %
# training @ iter =  3900
# epoch 38, minibatch 103/103, validation error 86.363636 %
# training @ iter =  4000
# epoch 39, minibatch 103/103, validation error 88.636364 %
# training @ iter =  4100
# epoch 40, minibatch 103/103, validation error 90.198864 %
# training @ iter =  4200
# epoch 41, minibatch 103/103, validation error 89.772727 %
# training @ iter =  4300
# epoch 42, minibatch 103/103, validation error 89.275568 %
# training @ iter =  4400
# epoch 43, minibatch 103/103, validation error 85.866477 %
# training @ iter =  4500
# epoch 44, minibatch 103/103, validation error 89.630682 %
# training @ iter =  4600
# epoch 45, minibatch 103/103, validation error 87.428977 %
# training @ iter =  4700
# epoch 46, minibatch 103/103, validation error 89.985795 %
# training @ iter =  4800
# epoch 47, minibatch 103/103, validation error 88.565341 %
# training @ iter =  4900
# epoch 48, minibatch 103/103, validation error 90.625000 %
# training @ iter =  5000
# epoch 49, minibatch 103/103, validation error 90.127841 %
# training @ iter =  5100
# epoch 50, minibatch 103/103, validation error 91.619318 %
# training @ iter =  5200
# epoch 51, minibatch 103/103, validation error 91.548295 %
# training @ iter =  5300
# epoch 52, minibatch 103/103, validation error 87.926136 %
# training @ iter =  5400
# epoch 53, minibatch 103/103, validation error 87.642045 %
# training @ iter =  5500
# epoch 54, minibatch 103/103, validation error 85.582386 %
# training @ iter =  5600
# epoch 55, minibatch 103/103, validation error 86.079545 %
# training @ iter =  5700
# epoch 56, minibatch 103/103, validation error 89.488636 %
# training @ iter =  5800
# epoch 57, minibatch 103/103, validation error 89.346591 %
# training @ iter =  5900
# epoch 58, minibatch 103/103, validation error 86.079545 %
# training @ iter =  6000
# epoch 59, minibatch 103/103, validation error 84.446023 %
#      epoch 59, minibatch 103/103, test error of best model 84.228756 %
# training @ iter =  6100
# epoch 60, minibatch 103/103, validation error 88.281250 %
# training @ iter =  6200
# epoch 61, minibatch 103/103, validation error 91.122159 %
# training @ iter =  6300
# epoch 62, minibatch 103/103, validation error 84.588068 %
# training @ iter =  6400
# epoch 63, minibatch 103/103, validation error 90.980114 %
# training @ iter =  6500
# epoch 64, minibatch 103/103, validation error 85.653409 %
# training @ iter =  6600
# epoch 65, minibatch 103/103, validation error 84.517045 %
# training @ iter =  6700
# epoch 66, minibatch 103/103, validation error 88.707386 %
# training @ iter =  6800
# training @ iter =  6900
# epoch 67, minibatch 103/103, validation error 88.139205 %
# training @ iter =  7000
# epoch 68, minibatch 103/103, validation error 86.150568 %
# training @ iter =  7100
# epoch 69, minibatch 103/103, validation error 85.085227 %
# training @ iter =  7200
# epoch 70, minibatch 103/103, validation error 87.642045 %
# training @ iter =  7300
# epoch 71, minibatch 103/103, validation error 90.696023 %
# training @ iter =  7400
# epoch 72, minibatch 103/103, validation error 88.281250 %
# training @ iter =  7500
# epoch 73, minibatch 103/103, validation error 87.926136 %
# training @ iter =  7600
# epoch 74, minibatch 103/103, validation error 84.659091 %
# training @ iter =  7700
# epoch 75, minibatch 103/103, validation error 86.221591 %
# training @ iter =  7800
# epoch 76, minibatch 103/103, validation error 91.264205 %
# training @ iter =  7900
# epoch 77, minibatch 103/103, validation error 86.718750 %
# training @ iter =  8000
# epoch 78, minibatch 103/103, validation error 88.636364 %
# training @ iter =  8100
# epoch 79, minibatch 103/103, validation error 90.625000 %
# training @ iter =  8200
# epoch 80, minibatch 103/103, validation error 91.335227 %
# training @ iter =  8300
# epoch 81, minibatch 103/103, validation error 89.985795 %
# training @ iter =  8400
# epoch 82, minibatch 103/103, validation error 89.559659 %
# training @ iter =  8500
# epoch 83, minibatch 103/103, validation error 89.772727 %
# training @ iter =  8600
# epoch 84, minibatch 103/103, validation error 86.505682 %
# training @ iter =  8700
# epoch 85, minibatch 103/103, validation error 92.258523 %
# training @ iter =  8800
# epoch 86, minibatch 103/103, validation error 89.204545 %
# training @ iter =  8900
# epoch 87, minibatch 103/103, validation error 89.488636 %
# training @ iter =  9000
# epoch 88, minibatch 103/103, validation error 86.789773 %
# training @ iter =  9100
# epoch 89, minibatch 103/103, validation error 86.789773 %
# training @ iter =  9200
# epoch 90, minibatch 103/103, validation error 86.789773 %
# training @ iter =  9300
# epoch 91, minibatch 103/103, validation error 84.659091 %
# training @ iter =  9400
# epoch 92, minibatch 103/103, validation error 88.778409 %
# training @ iter =  9500
# epoch 93, minibatch 103/103, validation error 89.701705 %
# training @ iter =  9600
# epoch 94, minibatch 103/103, validation error 84.019886 %
#      epoch 94, minibatch 103/103, test error of best model 83.674569 %
# training @ iter =  9700
# epoch 95, minibatch 103/103, validation error 90.269886 %
# training @ iter =  9800
# epoch 96, minibatch 103/103, validation error 88.281250 %
# training @ iter =  9900
# epoch 97, minibatch 103/103, validation error 89.417614 %
# training @ iter =  10000
# epoch 98, minibatch 103/103, validation error 89.843750 %
# training @ iter =  10100
# epoch 99, minibatch 103/103, validation error 90.696023 %
# training @ iter =  10200
# epoch 100, minibatch 103/103, validation error 88.068182 %
# training @ iter =  10300
# training @ iter =  10400
# epoch 101, minibatch 103/103, validation error 86.718750 %
# training @ iter =  10500
# epoch 102, minibatch 103/103, validation error 88.778409 %
# training @ iter =  10600
# epoch 103, minibatch 103/103, validation error 88.139205 %
# training @ iter =  10700
# epoch 104, minibatch 103/103, validation error 84.588068 %
# training @ iter =  10800
# epoch 105, minibatch 103/103, validation error 88.210227 %
# training @ iter =  10900
# epoch 106, minibatch 103/103, validation error 87.855114 %
# training @ iter =  11000
# epoch 107, minibatch 103/103, validation error 90.625000 %
# training @ iter =  11100
# epoch 108, minibatch 103/103, validation error 88.281250 %
# training @ iter =  11200
# epoch 109, minibatch 103/103, validation error 87.713068 %
# training @ iter =  11300
# epoch 110, minibatch 103/103, validation error 86.150568 %
# training @ iter =  11400
# epoch 111, minibatch 103/103, validation error 89.559659 %
# training @ iter =  11500
# epoch 112, minibatch 103/103, validation error 88.281250 %
# training @ iter =  11600
# epoch 113, minibatch 103/103, validation error 86.931818 %
# training @ iter =  11700
# epoch 114, minibatch 103/103, validation error 88.423295 %
# training @ iter =  11800
# epoch 115, minibatch 103/103, validation error 86.931818 %
# training @ iter =  11900
# epoch 116, minibatch 103/103, validation error 89.772727 %
# training @ iter =  12000
# epoch 117, minibatch 103/103, validation error 90.411932 %
# training @ iter =  12100
# epoch 118, minibatch 103/103, validation error 89.559659 %
# training @ iter =  12200
# epoch 119, minibatch 103/103, validation error 88.778409 %
# training @ iter =  12300
# epoch 120, minibatch 103/103, validation error 91.548295 %
# training @ iter =  12400
# epoch 121, minibatch 103/103, validation error 91.051136 %
# training @ iter =  12500
# epoch 122, minibatch 103/103, validation error 91.832386 %
# training @ iter =  12600
# epoch 123, minibatch 103/103, validation error 89.062500 %
# training @ iter =  12700
# epoch 124, minibatch 103/103, validation error 88.636364 %
# training @ iter =  12800
# epoch 125, minibatch 103/103, validation error 89.701705 %
# training @ iter =  12900
# epoch 126, minibatch 103/103, validation error 85.866477 %
# training @ iter =  13000
# epoch 127, minibatch 103/103, validation error 87.642045 %
# training @ iter =  13100
# epoch 128, minibatch 103/103, validation error 85.014205 %
# training @ iter =  13200
# epoch 129, minibatch 103/103, validation error 91.335227 %
# training @ iter =  13300
# epoch 130, minibatch 103/103, validation error 85.298295 %
# training @ iter =  13400
# epoch 131, minibatch 103/103, validation error 85.156250 %
# training @ iter =  13500
# epoch 132, minibatch 103/103, validation error 85.156250 %
# training @ iter =  13600
# epoch 133, minibatch 103/103, validation error 84.659091 %
# training @ iter =  13700
# training @ iter =  13800
# epoch 134, minibatch 103/103, validation error 87.855114 %
# training @ iter =  13900
# epoch 135, minibatch 103/103, validation error 83.735795 %
#      epoch 135, minibatch 103/103, test error of best model 83.047260 %
# training @ iter =  14000
# epoch 136, minibatch 103/103, validation error 84.588068 %
# training @ iter =  14100
# epoch 137, minibatch 103/103, validation error 89.062500 %
# training @ iter =  14200
# epoch 138, minibatch 103/103, validation error 87.144886 %
# training @ iter =  14300
# epoch 139, minibatch 103/103, validation error 85.440341 %
# training @ iter =  14400
# epoch 140, minibatch 103/103, validation error 86.789773 %
# training @ iter =  14500
# epoch 141, minibatch 103/103, validation error 88.210227 %
# training @ iter =  14600
# epoch 142, minibatch 103/103, validation error 91.122159 %
# training @ iter =  14700
# epoch 143, minibatch 103/103, validation error 87.642045 %
# training @ iter =  14800
# epoch 144, minibatch 103/103, validation error 86.079545 %
# training @ iter =  14900
# epoch 145, minibatch 103/103, validation error 85.866477 %
# training @ iter =  15000
# epoch 146, minibatch 103/103, validation error 88.920455 %
# training @ iter =  15100
# epoch 147, minibatch 103/103, validation error 85.369318 %
# training @ iter =  15200
# epoch 148, minibatch 103/103, validation error 85.014205 %
# training @ iter =  15300
# epoch 149, minibatch 103/103, validation error 89.275568 %
# training @ iter =  15400
# epoch 150, minibatch 103/103, validation error 87.713068 %
# training @ iter =  15500
# epoch 151, minibatch 103/103, validation error 87.500000 %
# training @ iter =  15600
# epoch 152, minibatch 103/103, validation error 91.264205 %
# training @ iter =  15700
# epoch 153, minibatch 103/103, validation error 91.477273 %
# training @ iter =  15800
# epoch 154, minibatch 103/103, validation error 92.116477 %
# training @ iter =  15900
# epoch 155, minibatch 103/103, validation error 88.281250 %
# training @ iter =  16000
# epoch 156, minibatch 103/103, validation error 93.181818 %
# training @ iter =  16100
# epoch 157, minibatch 103/103, validation error 91.264205 %
# training @ iter =  16200
# epoch 158, minibatch 103/103, validation error 92.826705 %
# training @ iter =  16300
# epoch 159, minibatch 103/103, validation error 92.471591 %
# training @ iter =  16400
# epoch 160, minibatch 103/103, validation error 90.696023 %
# training @ iter =  16500
# epoch 161, minibatch 103/103, validation error 88.423295 %
# training @ iter =  16600
# epoch 162, minibatch 103/103, validation error 86.008523 %
# training @ iter =  16700
# epoch 163, minibatch 103/103, validation error 90.909091 %
# training @ iter =  16800
# epoch 164, minibatch 103/103, validation error 91.903409 %
# training @ iter =  16900
# epoch 165, minibatch 103/103, validation error 91.974432 %
# training @ iter =  17000
# epoch 166, minibatch 103/103, validation error 87.073864 %
# training @ iter =  17100
# training @ iter =  17200
# epoch 167, minibatch 103/103, validation error 88.778409 %
# training @ iter =  17300
# epoch 168, minibatch 103/103, validation error 92.116477 %
# training @ iter =  17400
# epoch 169, minibatch 103/103, validation error 91.193182 %
# training @ iter =  17500
# epoch 170, minibatch 103/103, validation error 90.269886 %
# training @ iter =  17600
# epoch 171, minibatch 103/103, validation error 89.133523 %
# training @ iter =  17700
# epoch 172, minibatch 103/103, validation error 88.494318 %
# training @ iter =  17800
# epoch 173, minibatch 103/103, validation error 89.772727 %
# training @ iter =  17900
# epoch 174, minibatch 103/103, validation error 89.701705 %
# training @ iter =  18000
# epoch 175, minibatch 103/103, validation error 84.801136 %
# training @ iter =  18100
# epoch 176, minibatch 103/103, validation error 89.559659 %
# training @ iter =  18200
# epoch 177, minibatch 103/103, validation error 90.553977 %
# training @ iter =  18300
# epoch 178, minibatch 103/103, validation error 90.696023 %
# training @ iter =  18400
# epoch 179, minibatch 103/103, validation error 90.696023 %
# training @ iter =  18500
# epoch 180, minibatch 103/103, validation error 89.559659 %
# training @ iter =  18600
# epoch 181, minibatch 103/103, validation error 89.559659 %
# training @ iter =  18700
# epoch 182, minibatch 103/103, validation error 91.406250 %
# training @ iter =  18800
# epoch 183, minibatch 103/103, validation error 90.909091 %
# training @ iter =  18900
# epoch 184, minibatch 103/103, validation error 88.352273 %
# training @ iter =  19000
# epoch 185, minibatch 103/103, validation error 91.619318 %
# training @ iter =  19100
# epoch 186, minibatch 103/103, validation error 91.335227 %
# training @ iter =  19200
# epoch 187, minibatch 103/103, validation error 92.897727 %
# training @ iter =  19300
# epoch 188, minibatch 103/103, validation error 93.181818 %
# training @ iter =  19400
# epoch 189, minibatch 103/103, validation error 91.974432 %
# training @ iter =  19500
# epoch 190, minibatch 103/103, validation error 92.045455 %
# training @ iter =  19600
# epoch 191, minibatch 103/103, validation error 91.832386 %
# training @ iter =  19700
# epoch 192, minibatch 103/103, validation error 91.264205 %
# training @ iter =  19800
# epoch 193, minibatch 103/103, validation error 90.909091 %
# training @ iter =  19900
# epoch 194, minibatch 103/103, validation error 89.204545 %
# training @ iter =  20000
# epoch 195, minibatch 103/103, validation error 90.127841 %
# training @ iter =  20100
# epoch 196, minibatch 103/103, validation error 90.411932 %
# training @ iter =  20200
# epoch 197, minibatch 103/103, validation error 88.707386 %
# training @ iter =  20300
# epoch 198, minibatch 103/103, validation error 86.434659 %
# training @ iter =  20400
# epoch 199, minibatch 103/103, validation error 88.423295 %
# training @ iter =  20500
# epoch 200, minibatch 103/103, validation error 88.636364 %
# training @ iter =  20600
# training @ iter =  20700
# epoch 201, minibatch 103/103, validation error 89.843750 %
# training @ iter =  20800
# epoch 202, minibatch 103/103, validation error 90.340909 %
# training @ iter =  20900
# epoch 203, minibatch 103/103, validation error 91.193182 %
# training @ iter =  21000
# epoch 204, minibatch 103/103, validation error 86.576705 %
# training @ iter =  21100
# epoch 205, minibatch 103/103, validation error 89.843750 %
# training @ iter =  21200
# epoch 206, minibatch 103/103, validation error 90.056818 %
# training @ iter =  21300
# epoch 207, minibatch 103/103, validation error 91.264205 %
# training @ iter =  21400
# epoch 208, minibatch 103/103, validation error 90.127841 %
# training @ iter =  21500
# epoch 209, minibatch 103/103, validation error 90.909091 %
# training @ iter =  21600
# epoch 210, minibatch 103/103, validation error 88.707386 %
# training @ iter =  21700
# epoch 211, minibatch 103/103, validation error 86.931818 %
# training @ iter =  21800
# epoch 212, minibatch 103/103, validation error 89.488636 %
# training @ iter =  21900
# epoch 213, minibatch 103/103, validation error 90.482955 %
# training @ iter =  22000
# epoch 214, minibatch 103/103, validation error 90.127841 %
# training @ iter =  22100
# epoch 215, minibatch 103/103, validation error 88.281250 %
# training @ iter =  22200
# epoch 216, minibatch 103/103, validation error 88.920455 %
# training @ iter =  22300
# epoch 217, minibatch 103/103, validation error 88.281250 %
# training @ iter =  22400
# epoch 218, minibatch 103/103, validation error 91.548295 %
# training @ iter =  22500
# epoch 219, minibatch 103/103, validation error 91.477273 %
# training @ iter =  22600
# epoch 220, minibatch 103/103, validation error 90.625000 %
# training @ iter =  22700
# epoch 221, minibatch 103/103, validation error 92.045455 %
# training @ iter =  22800
# epoch 222, minibatch 103/103, validation error 91.335227 %
# training @ iter =  22900
# epoch 223, minibatch 103/103, validation error 89.133523 %
# training @ iter =  23000
# epoch 224, minibatch 103/103, validation error 90.127841 %
# training @ iter =  23100
# epoch 225, minibatch 103/103, validation error 89.559659 %
# training @ iter =  23200
# epoch 226, minibatch 103/103, validation error 90.625000 %
# training @ iter =  23300
# epoch 227, minibatch 103/103, validation error 91.335227 %
# training @ iter =  23400
# epoch 228, minibatch 103/103, validation error 90.838068 %
# training @ iter =  23500
# epoch 229, minibatch 103/103, validation error 90.909091 %
# training @ iter =  23600
# epoch 230, minibatch 103/103, validation error 89.417614 %
# training @ iter =  23700
# epoch 231, minibatch 103/103, validation error 85.156250 %
# training @ iter =  23800
# epoch 232, minibatch 103/103, validation error 87.642045 %
# training @ iter =  23900
# epoch 233, minibatch 103/103, validation error 86.505682 %
# training @ iter =  24000
# training @ iter =  24100
# epoch 234, minibatch 103/103, validation error 88.920455 %
# training @ iter =  24200
# epoch 235, minibatch 103/103, validation error 86.008523 %
# training @ iter =  24300
# epoch 236, minibatch 103/103, validation error 86.434659 %
# training @ iter =  24400
# epoch 237, minibatch 103/103, validation error 86.221591 %
# training @ iter =  24500
# epoch 238, minibatch 103/103, validation error 87.144886 %
# training @ iter =  24600
# epoch 239, minibatch 103/103, validation error 88.494318 %
# training @ iter =  24700
# epoch 240, minibatch 103/103, validation error 88.352273 %
# training @ iter =  24800
# epoch 241, minibatch 103/103, validation error 89.772727 %
# training @ iter =  24900
# epoch 242, minibatch 103/103, validation error 88.849432 %
# training @ iter =  25000
# epoch 243, minibatch 103/103, validation error 91.193182 %
# training @ iter =  25100
# epoch 244, minibatch 103/103, validation error 88.281250 %
# training @ iter =  25200
# epoch 245, minibatch 103/103, validation error 88.352273 %
# training @ iter =  25300
# epoch 246, minibatch 103/103, validation error 88.636364 %
# training @ iter =  25400
# epoch 247, minibatch 103/103, validation error 87.855114 %
# training @ iter =  25500
# epoch 248, minibatch 103/103, validation error 85.937500 %
# training @ iter =  25600
# epoch 249, minibatch 103/103, validation error 86.221591 %
# training @ iter =  25700
# epoch 250, minibatch 103/103, validation error 87.357955 %
# training @ iter =  25800
# epoch 251, minibatch 103/103, validation error 86.789773 %
# training @ iter =  25900
# epoch 252, minibatch 103/103, validation error 89.701705 %
# training @ iter =  26000
# epoch 253, minibatch 103/103, validation error 89.701705 %
# training @ iter =  26100
# epoch 254, minibatch 103/103, validation error 89.488636 %
# training @ iter =  26200
# epoch 255, minibatch 103/103, validation error 87.713068 %
# training @ iter =  26300
# epoch 256, minibatch 103/103, validation error 87.997159 %
# training @ iter =  26400
# epoch 257, minibatch 103/103, validation error 89.914773 %
# training @ iter =  26500
# epoch 258, minibatch 103/103, validation error 88.068182 %
# training @ iter =  26600
# epoch 259, minibatch 103/103, validation error 89.559659 %
# training @ iter =  26700
# epoch 260, minibatch 103/103, validation error 87.073864 %
# training @ iter =  26800
# epoch 261, minibatch 103/103, validation error 87.286932 %
# training @ iter =  26900
# epoch 262, minibatch 103/103, validation error 85.511364 %
# training @ iter =  27000
# epoch 263, minibatch 103/103, validation error 87.428977 %
# training @ iter =  27100
# epoch 264, minibatch 103/103, validation error 86.789773 %
# training @ iter =  27200
# epoch 265, minibatch 103/103, validation error 88.778409 %
# training @ iter =  27300
# epoch 266, minibatch 103/103, validation error 88.707386 %
# training @ iter =  27400
# training @ iter =  27500
# epoch 267, minibatch 103/103, validation error 89.701705 %
# training @ iter =  27600
# epoch 268, minibatch 103/103, validation error 90.838068 %
# training @ iter =  27700
# epoch 269, minibatch 103/103, validation error 91.122159 %
# training @ iter =  27800
# epoch 270, minibatch 103/103, validation error 92.329545 %
# training @ iter =  27900
# epoch 271, minibatch 103/103, validation error 91.477273 %
# training @ iter =  28000
# epoch 272, minibatch 103/103, validation error 91.761364 %
# training @ iter =  28100
# epoch 273, minibatch 103/103, validation error 91.477273 %
# training @ iter =  28200
# epoch 274, minibatch 103/103, validation error 90.411932 %
# training @ iter =  28300
# epoch 275, minibatch 103/103, validation error 91.477273 %
# training @ iter =  28400
# epoch 276, minibatch 103/103, validation error 89.417614 %
# training @ iter =  28500
# epoch 277, minibatch 103/103, validation error 90.340909 %
# training @ iter =  28600
# epoch 278, minibatch 103/103, validation error 90.127841 %
# training @ iter =  28700
# epoch 279, minibatch 103/103, validation error 88.849432 %
# training @ iter =  28800
# epoch 280, minibatch 103/103, validation error 88.423295 %
# training @ iter =  28900
# epoch 281, minibatch 103/103, validation error 87.286932 %
# training @ iter =  29000
# epoch 282, minibatch 103/103, validation error 86.718750 %
# training @ iter =  29100
# epoch 283, minibatch 103/103, validation error 86.789773 %
# training @ iter =  29200
# epoch 284, minibatch 103/103, validation error 92.329545 %
# training @ iter =  29300
# epoch 285, minibatch 103/103, validation error 91.406250 %
# training @ iter =  29400
# epoch 286, minibatch 103/103, validation error 91.193182 %
# training @ iter =  29500
# epoch 287, minibatch 103/103, validation error 92.187500 %
# training @ iter =  29600
# epoch 288, minibatch 103/103, validation error 91.761364 %
# training @ iter =  29700
# epoch 289, minibatch 103/103, validation error 88.423295 %
# training @ iter =  29800
# epoch 290, minibatch 103/103, validation error 91.335227 %
# training @ iter =  29900
# epoch 291, minibatch 103/103, validation error 90.767045 %
# training @ iter =  30000
# Optimization complete.
# Best validation score of 83.735795 % obtained at iteration 13905, with test performance 83.047260 %
# The training process for function test_noise_inject_at_weight ran for 3.56m

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=100,
             batch_size=128, n_hidden=500, n_hiddenLayers=3,
             verbose=True, smaller_set=True)
# Out:
# ... building the model
# ... training
# training @ iter =  0
# training @ iter =  100
# epoch 1, minibatch 103/103, validation error 81.392045 %
#      epoch 1, minibatch 103/103, test error of best model 80.414871 %
# training @ iter =  200
# epoch 2, minibatch 103/103, validation error 81.392045 %
# training @ iter =  300
# epoch 3, minibatch 103/103, validation error 81.392045 %
# training @ iter =  400
# epoch 4, minibatch 103/103, validation error 81.392045 %
# training @ iter =  500
# epoch 5, minibatch 103/103, validation error 81.392045 %
# training @ iter =  600
# epoch 6, minibatch 103/103, validation error 81.392045 %
# training @ iter =  700
# epoch 7, minibatch 103/103, validation error 81.392045 %
# training @ iter =  800
# epoch 8, minibatch 103/103, validation error 81.392045 %
# training @ iter =  900
# epoch 9, minibatch 103/103, validation error 81.534091 %
# training @ iter =  1000
# epoch 10, minibatch 103/103, validation error 81.250000 %
#      epoch 10, minibatch 103/103, test error of best model 80.226293 %
# training @ iter =  1100
# epoch 11, minibatch 103/103, validation error 80.894886 %
#      epoch 11, minibatch 103/103, test error of best model 80.030018 %
# training @ iter =  1200
# epoch 12, minibatch 103/103, validation error 80.468750 %
#      epoch 12, minibatch 103/103, test error of best model 79.768319 %
# training @ iter =  1300
# epoch 13, minibatch 103/103, validation error 80.255682 %
#      epoch 13, minibatch 103/103, test error of best model 79.614378 %
# training @ iter =  1400
# epoch 14, minibatch 103/103, validation error 79.971591 %
#      epoch 14, minibatch 103/103, test error of best model 79.341133 %
# training @ iter =  1500
# epoch 15, minibatch 103/103, validation error 79.829545 %
#      epoch 15, minibatch 103/103, test error of best model 79.144858 %
# training @ iter =  1600
# epoch 16, minibatch 103/103, validation error 79.758523 %
#      epoch 16, minibatch 103/103, test error of best model 78.929341 %
# training @ iter =  1700
# epoch 17, minibatch 103/103, validation error 79.616477 %
#      epoch 17, minibatch 103/103, test error of best model 78.652248 %
# training @ iter =  1800
# epoch 18, minibatch 103/103, validation error 79.758523 %
# training @ iter =  1900
# epoch 19, minibatch 103/103, validation error 79.616477 %
# training @ iter =  2000
# epoch 20, minibatch 103/103, validation error 79.403409 %
#      epoch 20, minibatch 103/103, test error of best model 78.071121 %
# training @ iter =  2100
# epoch 21, minibatch 103/103, validation error 79.616477 %
# training @ iter =  2200
# epoch 22, minibatch 103/103, validation error 79.048295 %
#      epoch 22, minibatch 103/103, test error of best model 77.601601 %
# training @ iter =  2300
# epoch 23, minibatch 103/103, validation error 78.835227 %
#      epoch 23, minibatch 103/103, test error of best model 77.328356 %
# training @ iter =  2400
# epoch 24, minibatch 103/103, validation error 78.196023 %
#      epoch 24, minibatch 103/103, test error of best model 77.008929 %
# training @ iter =  2500
# epoch 25, minibatch 103/103, validation error 77.982955 %
#      epoch 25, minibatch 103/103, test error of best model 76.624076 %
# training @ iter =  2600
# epoch 26, minibatch 103/103, validation error 77.698864 %
#      epoch 26, minibatch 103/103, test error of best model 76.150708 %
# training @ iter =  2700
# epoch 27, minibatch 103/103, validation error 76.988636 %
#      epoch 27, minibatch 103/103, test error of best model 75.596521 %
# training @ iter =  2800
# epoch 28, minibatch 103/103, validation error 76.349432 %
#      epoch 28, minibatch 103/103, test error of best model 75.080819 %
# training @ iter =  2900
# epoch 29, minibatch 103/103, validation error 75.710227 %
#      epoch 29, minibatch 103/103, test error of best model 74.491995 %
# training @ iter =  3000
# epoch 30, minibatch 103/103, validation error 74.786932 %
#      epoch 30, minibatch 103/103, test error of best model 73.968596 %
# training @ iter =  3100
# epoch 31, minibatch 103/103, validation error 74.218750 %
#      epoch 31, minibatch 103/103, test error of best model 73.406712 %
# training @ iter =  3200
# epoch 32, minibatch 103/103, validation error 73.366477 %
#      epoch 32, minibatch 103/103, test error of best model 72.852525 %
# training @ iter =  3300
# epoch 33, minibatch 103/103, validation error 72.585227 %
#      epoch 33, minibatch 103/103, test error of best model 72.440733 %
# training @ iter =  3400
# training @ iter =  3500
# epoch 34, minibatch 103/103, validation error 72.372159 %
#      epoch 34, minibatch 103/103, test error of best model 71.871151 %
# training @ iter =  3600
# epoch 35, minibatch 103/103, validation error 71.377841 %
#      epoch 35, minibatch 103/103, test error of best model 71.432420 %
# training @ iter =  3700
# epoch 36, minibatch 103/103, validation error 70.170455 %
#      epoch 36, minibatch 103/103, test error of best model 70.870536 %
# training @ iter =  3800
# epoch 37, minibatch 103/103, validation error 70.312500 %
# training @ iter =  3900
# epoch 38, minibatch 103/103, validation error 69.389205 %
#      epoch 38, minibatch 103/103, test error of best model 69.854526 %
# training @ iter =  4000
# epoch 39, minibatch 103/103, validation error 68.252841 %
#      epoch 39, minibatch 103/103, test error of best model 69.188732 %
# training @ iter =  4100
# epoch 40, minibatch 103/103, validation error 67.755682 %
#      epoch 40, minibatch 103/103, test error of best model 68.588362 %
# training @ iter =  4200
# epoch 41, minibatch 103/103, validation error 67.187500 %
#      epoch 41, minibatch 103/103, test error of best model 68.057266 %
# training @ iter =  4300
# epoch 42, minibatch 103/103, validation error 66.619318 %
#      epoch 42, minibatch 103/103, test error of best model 67.410714 %
# training @ iter =  4400
# epoch 43, minibatch 103/103, validation error 66.051136 %
#      epoch 43, minibatch 103/103, test error of best model 66.698738 %
# training @ iter =  4500
# epoch 44, minibatch 103/103, validation error 65.269886 %
#      epoch 44, minibatch 103/103, test error of best model 66.106065 %
# training @ iter =  4600
# epoch 45, minibatch 103/103, validation error 64.559659 %
#      epoch 45, minibatch 103/103, test error of best model 65.174723 %
# training @ iter =  4700
# epoch 46, minibatch 103/103, validation error 63.849432 %
#      epoch 46, minibatch 103/103, test error of best model 64.358836 %
# training @ iter =  4800
# epoch 47, minibatch 103/103, validation error 63.281250 %
#      epoch 47, minibatch 103/103, test error of best model 63.535252 %
# training @ iter =  4900
# epoch 48, minibatch 103/103, validation error 62.428977 %
#      epoch 48, minibatch 103/103, test error of best model 62.623153 %
# training @ iter =  5000
# epoch 49, minibatch 103/103, validation error 61.505682 %
#      epoch 49, minibatch 103/103, test error of best model 61.737993 %
# training @ iter =  5100
# epoch 50, minibatch 103/103, validation error 60.866477 %
#      epoch 50, minibatch 103/103, test error of best model 60.914409 %
# training @ iter =  5200
# epoch 51, minibatch 103/103, validation error 59.730114 %
#      epoch 51, minibatch 103/103, test error of best model 60.094674 %
# training @ iter =  5300
# epoch 52, minibatch 103/103, validation error 58.380682 %
#      epoch 52, minibatch 103/103, test error of best model 59.301878 %
# training @ iter =  5400
# epoch 53, minibatch 103/103, validation error 57.386364 %
#      epoch 53, minibatch 103/103, test error of best model 58.347445 %
# training @ iter =  5500
# epoch 54, minibatch 103/103, validation error 56.321023 %
#      epoch 54, minibatch 103/103, test error of best model 57.500770 %
# training @ iter =  5600
# epoch 55, minibatch 103/103, validation error 55.539773 %
#      epoch 55, minibatch 103/103, test error of best model 56.573276 %
# training @ iter =  5700
# epoch 56, minibatch 103/103, validation error 54.403409 %
#      epoch 56, minibatch 103/103, test error of best model 55.741995 %
# training @ iter =  5800
# epoch 57, minibatch 103/103, validation error 53.622159 %
#      epoch 57, minibatch 103/103, test error of best model 54.945351 %
# training @ iter =  5900
# epoch 58, minibatch 103/103, validation error 52.840909 %
#      epoch 58, minibatch 103/103, test error of best model 54.021706 %
# training @ iter =  6000
# epoch 59, minibatch 103/103, validation error 52.343750 %
#      epoch 59, minibatch 103/103, test error of best model 53.321275 %
# training @ iter =  6100
# epoch 60, minibatch 103/103, validation error 51.278409 %
#      epoch 60, minibatch 103/103, test error of best model 52.559267 %
# training @ iter =  6200
# epoch 61, minibatch 103/103, validation error 50.355114 %
#      epoch 61, minibatch 103/103, test error of best model 51.912716 %
# training @ iter =  6300
# epoch 62, minibatch 103/103, validation error 49.928977 %
#      epoch 62, minibatch 103/103, test error of best model 51.300800 %
# training @ iter =  6400
# epoch 63, minibatch 103/103, validation error 49.076705 %
#      epoch 63, minibatch 103/103, test error of best model 50.481065 %
# training @ iter =  6500
# epoch 64, minibatch 103/103, validation error 48.295455 %
#      epoch 64, minibatch 103/103, test error of best model 49.942272 %
# training @ iter =  6600
# epoch 65, minibatch 103/103, validation error 47.869318 %
#      epoch 65, minibatch 103/103, test error of best model 49.264932 %
# training @ iter =  6700
# epoch 66, minibatch 103/103, validation error 46.875000 %
#      epoch 66, minibatch 103/103, test error of best model 48.687654 %
# training @ iter =  6800
# training @ iter =  6900
# epoch 67, minibatch 103/103, validation error 45.951705 %
#      epoch 67, minibatch 103/103, test error of best model 48.025708 %
# training @ iter =  7000
# epoch 68, minibatch 103/103, validation error 44.957386 %
#      epoch 68, minibatch 103/103, test error of best model 47.479218 %
# training @ iter =  7100
# epoch 69, minibatch 103/103, validation error 44.318182 %
#      epoch 69, minibatch 103/103, test error of best model 46.998153 %
# training @ iter =  7200
# epoch 70, minibatch 103/103, validation error 43.750000 %
#      epoch 70, minibatch 103/103, test error of best model 46.705665 %
# training @ iter =  7300
# epoch 71, minibatch 103/103, validation error 43.110795 %
#      epoch 71, minibatch 103/103, test error of best model 46.417026 %
# training @ iter =  7400
# epoch 72, minibatch 103/103, validation error 42.897727 %
#      epoch 72, minibatch 103/103, test error of best model 46.028325 %
# training @ iter =  7500
# epoch 73, minibatch 103/103, validation error 42.542614 %
#      epoch 73, minibatch 103/103, test error of best model 45.685807 %
# training @ iter =  7600
# epoch 74, minibatch 103/103, validation error 42.613636 %
# training @ iter =  7700
# epoch 75, minibatch 103/103, validation error 41.974432 %
#      epoch 75, minibatch 103/103, test error of best model 45.000770 %
# training @ iter =  7800
# epoch 76, minibatch 103/103, validation error 42.045455 %
# training @ iter =  7900
# epoch 77, minibatch 103/103, validation error 41.903409 %
#      epoch 77, minibatch 103/103, test error of best model 44.373461 %
# training @ iter =  8000
# epoch 78, minibatch 103/103, validation error 41.619318 %
#      epoch 78, minibatch 103/103, test error of best model 44.050185 %
# training @ iter =  8100
# epoch 79, minibatch 103/103, validation error 41.264205 %
#      epoch 79, minibatch 103/103, test error of best model 43.765394 %
# training @ iter =  8200
# epoch 80, minibatch 103/103, validation error 41.193182 %
#      epoch 80, minibatch 103/103, test error of best model 43.372845 %
# training @ iter =  8300
# epoch 81, minibatch 103/103, validation error 40.767045 %
#      epoch 81, minibatch 103/103, test error of best model 43.041872 %
# training @ iter =  8400
# epoch 82, minibatch 103/103, validation error 40.056818 %
#      epoch 82, minibatch 103/103, test error of best model 42.645474 %
# training @ iter =  8500
# epoch 83, minibatch 103/103, validation error 39.843750 %
#      epoch 83, minibatch 103/103, test error of best model 42.291410 %
# training @ iter =  8600
# epoch 84, minibatch 103/103, validation error 40.056818 %
# training @ iter =  8700
# epoch 85, minibatch 103/103, validation error 39.772727 %
#      epoch 85, minibatch 103/103, test error of best model 41.552494 %
# training @ iter =  8800
# epoch 86, minibatch 103/103, validation error 39.772727 %
# training @ iter =  8900
# epoch 87, minibatch 103/103, validation error 39.559659 %
#      epoch 87, minibatch 103/103, test error of best model 40.925185 %
# training @ iter =  9000
# epoch 88, minibatch 103/103, validation error 39.417614 %
#      epoch 88, minibatch 103/103, test error of best model 40.586515 %
# training @ iter =  9100
# epoch 89, minibatch 103/103, validation error 38.707386 %
#      epoch 89, minibatch 103/103, test error of best model 40.290179 %
# training @ iter =  9200
# epoch 90, minibatch 103/103, validation error 38.707386 %
# training @ iter =  9300
# epoch 91, minibatch 103/103, validation error 38.565341 %
#      epoch 91, minibatch 103/103, test error of best model 39.893781 %
# training @ iter =  9400
# epoch 92, minibatch 103/103, validation error 38.423295 %
#      epoch 92, minibatch 103/103, test error of best model 39.670567 %
# training @ iter =  9500
# epoch 93, minibatch 103/103, validation error 38.352273 %
#      epoch 93, minibatch 103/103, test error of best model 39.466595 %
# training @ iter =  9600
# epoch 94, minibatch 103/103, validation error 38.423295 %
# training @ iter =  9700
# epoch 95, minibatch 103/103, validation error 38.068182 %
#      epoch 95, minibatch 103/103, test error of best model 39.174107 %
# training @ iter =  9800
# epoch 96, minibatch 103/103, validation error 37.713068 %
#      epoch 96, minibatch 103/103, test error of best model 38.977833 %
# training @ iter =  9900
# epoch 97, minibatch 103/103, validation error 37.784091 %
# training @ iter =  10000
# epoch 98, minibatch 103/103, validation error 37.926136 %
# training @ iter =  10100
# epoch 99, minibatch 103/103, validation error 37.642045 %
#      epoch 99, minibatch 103/103, test error of best model 38.442888 %
# training @ iter =  10200
# epoch 100, minibatch 103/103, validation error 37.571023 %
#      epoch 100, minibatch 103/103, test error of best model 38.296644 %
# Optimization complete.
# Best validation score of 37.571023 % obtained at iteration 10300, with test performance 38.296644 %
# 0.0 1.0
# The training process for function test_mlp ran for 1.41m
